# %% [markdown]
# <a href="https://colab.research.google.com/github/JohanPaulo128/PROFE-ejemplo-Johan-Paulo-0016/blob/main/Profe_clase_automovil_Johan_0016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Johan Paulo Aros Reveles NL = 04 Fecha 29/Abril/2026
#
# #### Clase automovil con 3 atributos funciones leerdatos(), mostrardatos(), mostrardatos()
# #### que sea interactivo --> los input
# #### crear 3 objetos, carrro1, carro2, carro3
# #### No usar while true, if, for, ni listas y diccionarios
#
# ![texto del vínculo](https://raw.githubusercontent.com/JohanPaulo128/PROFE-ejemplo-Johan-Paulo-0016/refs/heads/main/infoprofevehiculo.PNG)

# %%
# Clase automovil, atributos, marca, placa, precio
# funcones leerdatos(), mostrardatos()
# crear 3 objetos carro1, carro2, carro3

class Automovil:
    def __init__(self, marca, placa, precio):
        self.marca = marca
        self.placa = placa
        self.precio = precio

    def leerdatos(self):
        self.marca = input("Ingrese la marca del automovil: ")
        self.placa = input("Ingrese la placa del automovil: ")
        self.precio = input("Ingrese el precio del automovil: ")

    def mostrardatos(self):
        print("Marca: ", self.marca)
        print("Placa: ", self.placa)
        print("Precio: ", self.precio)

# fin de la clase automovil
# creando los objetos carro1, carro2, carro3
print("Carro numero 1")
carro1 = Automovil("", "", 0.0)
carro1.leerdatos()
carro1.mostrardatos()
print("*_*_*_*_*_*_*_*_*_*_*_*_*_*")

print("Carro numero 2")
carro2 = Automovil("", "", 0.0)
carro2.leerdatos()
carro2.mostrardatos()
print("*_*_*_*_*_*_*_*_*_*_*_*_*_*")

print("Carro numero 3")
carro3 = Automovil("", "", 0.0)
carro3.leerdatos()
carro3.mostrardatos()
print("*_*_*_*_*_*_*_*_*_*_*_*_*_*")

print("Software desarollado por Johan Paulo Nl = 04")
print("*_*_*_*_*_*_*_*_*_*_*_*_*_*")
#mostrar los datos de los objetos carro1, carro2. carro3
# Out:
# Carro numero 1
# Ingrese la marca del automovil: Ford
# Ingrese la placa del automovil: 53453
# Ingrese el precio del automovil: 80,000
# Marca:  Ford
# Placa:  53453
# Precio:  80,000
# *_*_*_*_*_*_*_*_*_*_*_*_*_*
# Carro numero 2
# Ingrese la marca del automovil: Nissan
# Ingrese la placa del automovil: 3464634
# Ingrese el precio del automovil: 50,000
# Marca:  Nissan
# Placa:  3464634
# Precio:  50,000
# *_*_*_*_*_*_*_*_*_*_*_*_*_*
# Carro numero 3
# Ingrese la marca del automovil: Suzuki
# Ingrese la placa del automovil: 3523523
# Ingrese el precio del automovil: 90,000
# Marca:  Suzuki
# Placa:  3523523
# Precio:  90,000
# *_*_*_*_*_*_*_*_*_*_*_*_*_*
# Software desarollado por Johan Paulo Nl = 04
# *_*_*_*_*_*_*_*_*_*_*_*_*_*

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/JohanPaulo128/PROFE-ejemplo-Johan-Paulo-0016/refs/heads/main/tldelprofe.png)
